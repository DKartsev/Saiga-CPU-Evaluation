# %% [markdown]
# #### Подключение Google Drive для доступа к проектным файлам

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #### Переход в рабочую директорию проекта и вывод её содержимого

# %%
project_path = '/content/drive/MyDrive/SaigaProject'

# %%
import os
os.chdir(project_path)
# !ls

# %% [markdown]
# #### Установка зависимостей

# %%
# !pip install --upgrade pip

# %%
# !pip install -r requirements.txt

# %% [markdown]
# #### Запуск основного приложения проекта

# %%
# !python app.py
